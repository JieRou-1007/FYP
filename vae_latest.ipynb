# %% [markdown]
# <a href="https://colab.research.google.com/github/JieRou-1007/FYP/blob/master/vae_latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pytorch/examples
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 2805, done.
# remote: Total 2805 (delta 0), reused 0 (delta 0), pack-reused 2805
# Receiving objects: 100% (2805/2805), 39.16 MiB | 19.86 MiB/s, done.
# Resolving deltas: 100% (1413/1413), done.

# %%
pip install -r /content/examples/vae/requirements.txt

# %%
# !python /content/examples/vae/main.py
# Out:
# Files already downloaded and verified
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2153.618896
# Train Epoch: 1 [1280/50000 (3%)]	Loss: 2118.403564
# Train Epoch: 1 [2560/50000 (5%)]	Loss: 2066.221436
# Train Epoch: 1 [3840/50000 (8%)]	Loss: 2033.538818
# Train Epoch: 1 [5120/50000 (10%)]	Loss: 2023.166748
# Train Epoch: 1 [6400/50000 (13%)]	Loss: 1989.298096
# Train Epoch: 1 [7680/50000 (15%)]	Loss: 1981.884399
# Train Epoch: 1 [8960/50000 (18%)]	Loss: 1966.565918
# Train Epoch: 1 [10240/50000 (20%)]	Loss: 1981.349365
# Train Epoch: 1 [11520/50000 (23%)]	Loss: 1974.226074
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1953.377441
# Train Epoch: 1 [14080/50000 (28%)]	Loss: 1949.640991
# Train Epoch: 1 [15360/50000 (31%)]	Loss: 1941.831787
# Train Epoch: 1 [16640/50000 (33%)]	Loss: 1951.290039
# Train Epoch: 1 [17920/50000 (36%)]	Loss: 1956.300415
# Train Epoch: 1 [19200/50000 (38%)]	Loss: 1934.650146
# Train Epoch: 1 [20480/50000 (41%)]	Loss: 1924.333740
# ...
