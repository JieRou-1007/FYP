# %% [markdown]
# <a href="https://colab.research.google.com/github/Shabi2000/blablabla/blob/master/stylegan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Tetratrio/stylegan2_pytorch.git
# Out:
# Cloning into 'stylegan2_pytorch'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 121 (delta 0), reused 1 (delta 0), pack-reused 115
# Receiving objects: 100% (121/121), 97.19 KiB | 12.15 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
# !pip install -r /content/stylegan2_pytorch/requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !python /content/stylegan2_pytorch/run_convert_from_tf.py --input=./drive/MyDrive/FreaGAN.pkl --output checkpoint
# Out:
# Converting tensorflow models and saving them...
# Done!

# %%
# !python /content/stylegan2_pytorch/run_generator.py generate_images --network=checkpoint/Gs.pth --seeds=35 --truncation_psi=1.0

from IPython.display import Image, display
display(Image("./results/seed0035.png", width=300, height=300))
num = input ("Y/N?:") 
print(num)
# Out:
#   0% 0/1 [00:00<?, ?it/s]
#
# Generating images...
#
#
# Done!
# 100% 1/1 [00:03<00:00,  3.91s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %%
# !python /content/stylegan2_pytorch/run_projector.py project_generated_images --network=./checkpoint/Gs.pth --seeds=35
# Out:
#   0% 0/1 [00:00<?, ?it/s]
#
# Generating images...
#
#
# Done!
# 100% 1/1 [00:03<00:00,  3.52s/it]
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:23<00:00, 24.0MB/s]
# Downloading: "https://github.com/richzhang/PerceptualSimilarity/blob/master/lpips/weights/v0.1/vgg.pth?raw=true" to /root/.cache/torch/hub/checkpoints/vgg.pth
# 100% 7.12k/7.12k [00:00<00:00, 20.7MB/s]
#
#
# Gathering dlatents...
#
#
# Done!
# 100% 10/10 [00:00<00:00, 15.83it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
# !python /content/stylegan2_pytorch/run_projector.py project_real_images --network=/content/checkpoint/Gs.pth --data /content/newimage
# Out:
# Loading images from "/content/newimage"...
# Traceback (most recent call last):
#   File "/content/stylegan2_pytorch/run_projector.py", line 401, in <module>
#     main()
#   File "/content/stylegan2_pytorch/run_projector.py", line 395, in main
#     project_real_images(G, args)
#   File "/content/stylegan2_pytorch/run_projector.py", line 373, in project_real_images
#     images = torch.stack(images).to(device)
# RuntimeError: stack expects each tensor to be equal size, but got [3, 1024, 1024] at entry 0 and [3, 600, 900] at entry 1

# %%
from IPython.display import Image, display
display(Image("./results/seed0035.png", width=300, height=300))

# %%
# !git clone https://github.com/rosinality/stylegan2-pytorch
# Out:
# Cloning into 'stylegan2-pytorch'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 353 (delta 2), reused 0 (delta 0), pack-reused 345
# Receiving objects: 100% (353/353), 122.50 MiB | 24.15 MiB/s, done.
# Resolving deltas: 100% (174/174), done.

# %%
# !pip install Ninja
# Out:
# ...
#      |████████████████████████████████| 112kB 12.4MB/s
# ...

# %%
# !python /content/stylegan2-pytorch2/projector.py --ckpt /content/checkpoint/Gs.pth --size 256 /content/results/seed0035.png
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Traceback (most recent call last):
#   File "/content/stylegan2-pytorch2/projector.py", line 13, in <module>
#     from model import Generator
#   File "/content/stylegan2-pytorch2/model.py", line 11, in <module>
#     from op import FusedLeakyReLU, fused_leaky_relu, upfirdn2d
#   File "/content/stylegan2-pytorch2/op/__init__.py", line 1, in <module>
#     from .fused_act import FusedLeakyReLU, fused_leaky_relu
#   File "/content/stylegan2-pytorch2/op/fused_act.py", line 15, in <module>
#     os.path.join(module_path, "fused_bias_act_kernel.cu"),
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/cpp_extension.py", line 980, in load
#     keep_intermediates=keep_intermediates)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/cpp_extension.py", line 1185, in _jit_compile
#     with_cuda=with_cuda)
# ...

# %%
# !python /content/stylegan2-pytorch2/closed_form_factorization.py /content/checkpoint/Gs.pth
# Out:
# Traceback (most recent call last):
#   File "/content/stylegan2-pytorch2/closed_form_factorization.py", line 21, in <module>
#     for k, v in ckpt["g_ema"].items()
# KeyError: 'g_ema'
